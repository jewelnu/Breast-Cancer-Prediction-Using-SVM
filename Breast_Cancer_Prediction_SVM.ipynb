# %% [markdown]
# <h3>Breast Cancer prediction Using SVM</h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Breast_Cancer_Diagnostic.csv')
df
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   radius_mean             569 non-null    float64
#  1   texture_mean            569 non-null    float64
#  2   perimeter_mean          569 non-null    float64
#  3   area_mean               569 non-null    float64
#  4   smoothness_mean         569 non-null    float64
#  5   compactness_mean        569 non-null    float64
#  6   concavity_mean          569 non-null    float64
#  7   concave points_mean     569 non-null    float64
#  8   symmetry_mean           569 non-null    float64
#  9   fractal_dimension_mean  569 non-null    float64
#  10  diagnosis               569 non-null    object
# dtypes: float64(10), object(1)
# memory usage: 49.0+ KB

# %%
X = df.drop('diagnosis', axis=1)
X
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
y= df.diagnosis
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# Few steps that you can lead me through now!
# * Importing classifier,
# * creating instance,
# * train (fit) the model on training data and
# * do the predictions for test data, right? <br>
#
# Let's do this step by step. Note, SVC (support vector classifier) is in the svm class!
#
# ### Importing and  training the Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(kernel='linear',C=30,gamma='auto')
#kernel{‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’} or callable, default=’rbf’, c=1,10,20,30

# %%
# training / fitting the model 
svm_model.fit(X_train,y_train)
# Out:
# SVC(C=30, gamma='auto', kernel='linear')

# %%
svm_model.score(X_test, y_test)
# Out:
# 0.9590643274853801

# %% [markdown]
# ### Predictions  on own data

# %%
svm_model.predict([[1.740, 1.91, 10.12, 585.0, 0.07944, 0.06376, 1.02881, 0.01329, 0.1473, 2.05580]])
# Out:
# c:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array(['M'], dtype=object)

# %% [markdown]
# ### Lets go with Grid search algorithm to find parameter for best score
# **GridSearchCV does exactly same thing as for loop above but in a single line of code**

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(SVC(gamma='auto'), {
    'C': [1,10,20,30],
    'kernel': ['rbf','linear'] # when we use three parameter then processing time is too high
}, cv=5)
clf.fit(X,y)
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.02050695, 0.90306964, 0.01806383, 4.83978729, 0.02141056,
#         3.38206077, 0.02256947, 3.62717729]),
#  'std_fit_time': array([0.00547726, 0.47027922, 0.00445332, 1.71192973, 0.00663094,
#         1.02429304, 0.00643082, 0.99770861]),
#  'mean_score_time': array([0.01355929, 0.00128422, 0.01541419, 0.00127335, 0.01586976,
#         0.        , 0.01290073, 0.00340257]),
#  'std_score_time': array([0.00271785, 0.00157491, 0.0022326 , 0.00176077, 0.00176343,
#         0.        , 0.00759168, 0.00495889]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
# ...

# %%
df_gd = pd.DataFrame(clf.cv_results_)
df_gd
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.020507      0.005477         0.013559        0.002718        1
# 1       0.903070      0.470279         0.001284        0.001575        1
# 2       0.018064      0.004453         0.015414        0.002233       10
# 3       4.839787      1.711930         0.001273        0.001761       10
# 4       0.021411      0.006631         0.015870        0.001763       20
# 5       3.382061      1.024293         0.000000        0.000000       20
# 6       0.022569      0.006431         0.012901        0.007592       30
# 7       3.627177      0.997709         0.003403        0.004959       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.710526
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.859649
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.701754
# ...

# %%
df_gd[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.716985
# 1        1       linear         0.906893
# 2       10          rbf         0.720556
# 3       10       linear         0.913895
# 4       20          rbf         0.720556
# 5       20       linear         0.917404
# 6       30          rbf         0.720556
# 7       30       linear         0.920913

# %%
clf.best_params_
# Out:
# {'C': 30, 'kernel': 'linear'}
